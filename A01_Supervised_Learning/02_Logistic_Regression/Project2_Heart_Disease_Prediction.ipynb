# %%
"""
Author: Ngo Van Uc
Date:
Contact:
"""

# %% [markdown]
# # Heart disease prediction using machine learning algorithm: Logistic Regression
# ## Content
# 1. Data collectin
# 2. Data preprocessing
# 3. Data visualization
# 4. Model training
# 5. Model tesing
# 6. Model evaluation
# 7. Model deployment

# %% [markdown]
# # 0. Imprt libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# # 1. Data collectioncollection

# %%
# Bộ dữ liệu được công khai tại
# https://www.kaggle.com/datasets/hashemi221022/diabetes

# Load dataset
data = pd.read_csv('../Datasets/heart_diesease_dataset/heart.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0     125.0   212    0        1    168.0      0      1.0      2
# 1   53    1   0     140.0   203    1        0    155.0      1      3.1      0
# 2   70    1   0     145.0   174    0        1    125.0      1      2.6      0
# 3   61    1   0     148.0   203    0        1    161.0      0      0.0      2
# 4   62    0   0     138.0   294    1        1    106.0      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# Bộ dữ liệu này có nhiều thông tin hơn, mỗi cột đều mang thông tin quan trọng khác nhau. Có thể áp dụng nhiều phương pháp trích xuất đặc trưng để cho ra kết quả mô hình tốt nhất. Mục đích cuối cùng của chúng ta là dự đoán cho cột target chính xác càng tốt.

# %% [markdown]
# # 2. Data preprocessing

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    1
# chol        0
# fbs         0
# restecg     0
# thalach     1
# exang       0
# oldpeak     1
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data = data.dropna()
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Trong bài này chúng ta không thực hiện các phân tích chuyên sâu vào dữ liệu, vì thế các bước tiền xử lý có thể sẽ được giản lược. Tuy nhiên vẫn áp dụng phép chuẩn hóa minmaxscaler. Chúng ta áp dụng phép chuẩn hóa cho các cột đặc trưng, tuy nhiên cột target chúng ta giữ nguyên.

# %%
scaler = MinMaxScaler()
data.iloc[:, :-1] = scaler.fit_transform(data.iloc[:, :-1])

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (818, 13)
# (818,)
# (205, 13)
# (205,)

# %% [markdown]
# # 3. Data visualization

# %% [markdown]
# # 4. Model training

# %%
# Initialize the model
logistic_regression_model = LogisticRegression()
# Training the model
logistic_regression_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # 5. Model testing

# %% [markdown]
# # 6. Model evaluation

# %%
# Predict on test data
predictions = logistic_regression_model.predict(x_test)

# %%
# Accuracy score
accuracy_score = accuracy_score(y_test, predictions)

# %%
accuracy_score
# Out:
# 0.8390243902439024

# %%
# Precission score
print(precision_score(y_test, predictions))
# Out:
# 0.8018018018018018

# %%
# F1-score
print(f1_score(y_test, predictions))
# Out:
# 0.8436018957345972

# %%
# Recall score
print(recall_score(y_test, predictions))
# Out:
# 0.89

# %%
# classification report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       105
#            1       0.80      0.89      0.84       100
#
#     accuracy                           0.84       205
#    macro avg       0.84      0.84      0.84       205
# weighted avg       0.84      0.84      0.84       205
